# %%
#create featureset for ML
import pandas as pd
file_name = "/Users/jedgore/Desktop/git/text_to_numbers/datapull/data/03_primary/betas_table.csv"
betas_table = pd.read_csv(file_name)
file_name = "/Users/jedgore/Desktop/git/text_to_numbers/datapull/data/02_intermediate/preprocessed_fred_data.csv"
fred_data = pd.read_csv(file_name)
file_name = "/Users/jedgore/Desktop/git/text_to_numbers/datapull/data/02_intermediate/preprocessed_etf_prices.csv"
etf_prices = pd.read_csv(file_name)

# %%
betas_table.columns
# Out:
# Index(['symbol', 'date', 'close', 'rsi', 'one_day_alpha', 'thirty_day_alpha',
#        'earnings_one_day_alpha', 'earnings_close_date', 'earnings_trade_date',
#        'fiscal_date_ending', 'daily_average_return', 'close_return',
#        'earnings_close_return', 'hyg_return', 'tlt_return', 'vb_return',
#        'vtv_return', 'vug_return', 'rut_return', 'spx_return', 'DGS10_return',
#        'DGS2_return', 'DTB3_return', 'DFF_return', 'T10Y2Y_return',
#        'T5YIE_return', 'BAMLH0A0HYM2_return', 'DEXUSEU_return', 'KCFSI_return',
#        'DRTSCILM_return', 'RSXFS_return', 'MARTSMPCSM44000USS_return',
#        'H8B1058NCBCMG_return', 'DCOILWTICO_return', 'VXVCLS_return',
#        'H8B1247NCBCMG_return', 'SP500_return', 'GASREGW_return',
#        'CSUSHPINSA_return', 'UNEMPLOY_return', 'daily_average_return.1',
#        'earnings_close_one_day_return', 'close_one_day_return',
#        'spx_one_day_return', 'close_thirty_day_return',
#        'spx_thirty_day_return', 'VXVCLS_return_coef',
#        'MARTSMPCSM44000USS_return_coef', 'BAMLH0A0HYM2_return_coef',
#        'vtv_return_coef', 'DTB3_return_coef', 'H8B1247NCBCMG_return_coef',
#        'earnings_close_return_coef', 'DFF_return_coef', 'UNEMPLOY_return_coef',
#        'GASREGW_return_coef', 'SP500_return_coef', 'spx_return_coef',
#        'T5YIE_return_coef', 'RSXFS_return_coef', 'tlt_return_coef',
#        'DEXUSEU_return_coef', 'rut_return_coef', 'vug_return_coef',
#        'H8B1058NCBCMG_return_coef', 'vb_return_coef', 'CSUSHPINSA_return_coef',
#        'DGS10_return_coef', 'DRTSCILM_return_coef', 'DCOILWTICO_return_coef',
#        'T10Y2Y_return_coef', 'KCFSI_return_coef', 'DGS2_return_coef',
#        'hyg_return_coef', 'alpha_target'],
#       dtype='object')

# %%
betas_features = ['symbol', 'date', 'close', 'rsi', 'one_day_alpha', 'thirty_day_alpha',
       'earnings_one_day_alpha', 'earnings_close_date', 'earnings_trade_date',
       'fiscal_date_ending', 'daily_average_return', 'close_return',
       'earnings_close_return','VXVCLS_return_coef',
       'MARTSMPCSM44000USS_return_coef', 'BAMLH0A0HYM2_return_coef',
       'vtv_return_coef', 'DTB3_return_coef', 'H8B1247NCBCMG_return_coef',
       'earnings_close_return_coef', 'DFF_return_coef', 'UNEMPLOY_return_coef',
       'GASREGW_return_coef', 'SP500_return_coef', 'spx_return_coef',
       'T5YIE_return_coef', 'RSXFS_return_coef', 'tlt_return_coef',
       'DEXUSEU_return_coef', 'rut_return_coef', 'vug_return_coef',
       'H8B1058NCBCMG_return_coef', 'vb_return_coef', 'CSUSHPINSA_return_coef',
       'DGS10_return_coef', 'DRTSCILM_return_coef', 'DCOILWTICO_return_coef',
       'T10Y2Y_return_coef', 'KCFSI_return_coef', 'DGS2_return_coef',
       'hyg_return_coef']

# %%
betas_table[betas_features]
# Out:
#        symbol        date  close        rsi  one_day_alpha  thirty_day_alpha  \
# 0      AXP US  2016-01-25  55.02   8.775994            NaN               NaN
# 1      AXP US  2016-01-26  55.09   9.373556            NaN               NaN
# 2      AXP US  2016-01-27  54.52   8.864363            NaN               NaN
# 3      AXP US  2016-01-28  52.88   7.587282            NaN               NaN
# 4      AXP US  2016-01-29  53.50  12.707408            NaN               NaN
# ...       ...         ...    ...        ...            ...               ...
# 26335  WFC US  2024-10-07  57.16  57.034198       0.011653          0.029589
# 26336  WFC US  2024-10-08  57.30  57.555470      -0.005767          0.029645
# 26337  WFC US  2024-10-09  57.54  58.485316      -0.001812          0.029821
# 26338  WFC US  2024-10-10  57.75  59.324989       0.005413          0.029482
# 26339  WFC US  2024-10-11  60.99  69.556030       0.050913          0.029252
#
#        earnings_one_day_alpha earnings_close_date  earnings_trade_date  \
# 0                         NaN          2016-01-25                    0
# 1                         NaN          2016-01-26                    0
# 2                         NaN          2016-01-27                    0
# 3                         NaN          2016-01-28                    0
# 4                         NaN          2016-01-29                    0
# ...                       ...                 ...                  ...
# 26335                0.010591          2024-10-07                    0
# 26336               -0.004027          2024-10-08                    0
# 26337               -0.002351          2024-10-09                    0
# 26338                0.001764          2024-10-10                    0
# 26339               -0.005191          2024-10-10                    1
#
#       fiscal_date_ending  ...  H8B1058NCBCMG_return_coef  vb_return_coef  \
# 0             2016-03-31  ...                        NaN             NaN
# 1             2016-03-31  ...                        NaN             NaN
# 2             2016-03-31  ...                        NaN             NaN
# 3             2016-03-31  ...                        NaN             NaN
# 4             2016-03-31  ...                        NaN             NaN
# ...                  ...  ...                        ...             ...
# 26335         2024-09-30  ...                  -0.000604        0.822318
# 26336         2024-09-30  ...                  -0.000603        0.822256
# 26337         2024-09-30  ...                  -0.000599        0.820198
# 26338         2024-09-30  ...                  -0.000597        0.823979
# 26339         2024-09-30  ...                  -0.000589        0.832990
#
#        CSUSHPINSA_return_coef  DGS10_return_coef  DRTSCILM_return_coef  \
# 0                         NaN                NaN                   NaN
# 1                         NaN                NaN                   NaN
# 2                         NaN                NaN                   NaN
# 3                         NaN                NaN                   NaN
# 4                         NaN                NaN                   NaN
# ...                       ...                ...                   ...
# 26335               -0.006276           0.113971             -0.026341
# 26336               -0.006962           0.116575             -0.026310
# 26337               -0.009528           0.119961             -0.026196
# 26338               -0.010798           0.121391             -0.026139
# 26339               -0.016503           0.121285             -0.025884
#
#        DCOILWTICO_return_coef  T10Y2Y_return_coef  KCFSI_return_coef  \
# 0                         NaN                 NaN                NaN
# 1                         NaN                 NaN                NaN
# 2                         NaN                 NaN                NaN
# 3                         NaN                 NaN                NaN
# 4                         NaN                 NaN                NaN
# ...                       ...                 ...                ...
# 26335                0.149082            0.010615           0.000543
# 26336                0.149709            0.010560           0.000544
# 26337                0.150712            0.010584           0.000549
# 26338                0.154982            0.010552           0.000551
# 26339                0.154515            0.010561           0.000560
#
#        DGS2_return_coef  hyg_return_coef
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ...                 ...              ...
# 26335          0.246784         1.313447
# 26336          0.247341         1.313189
# 26337          0.250556         1.306340
# 26338          0.251917         1.311779
# 26339          0.251907         1.331226
#
# [26340 rows x 41 columns]
